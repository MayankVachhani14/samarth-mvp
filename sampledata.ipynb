# %%
import pandas as pd

# small sample dataset (for demo)
data = [
    ["Gujarat", "Ahmedabad", "Cotton", 2018, 250000],
    ["Gujarat", "Ahmedabad", "Cotton", 2019, 260000],
    ["Gujarat", "Ahmedabad", "Cotton", 2020, 255000],
    ["Gujarat", "Ahmedabad", "Wheat", 2018, 150000],
    ["Gujarat", "Ahmedabad", "Wheat", 2019, 158000],
    ["Gujarat", "Ahmedabad", "Wheat", 2020, 165000],
    ["Gujarat", "Rajkot", "Groundnut", 2018, 320000],
    ["Gujarat", "Rajkot", "Groundnut", 2019, 350000],
    ["Gujarat", "Rajkot", "Groundnut", 2020, 345000],
    ["Maharashtra", "Pune", "Sugarcane", 2018, 900000],
    ["Maharashtra", "Pune", "Sugarcane", 2019, 880000],
    ["Maharashtra", "Pune", "Sugarcane", 2020, 910000],
    ["Maharashtra", "Nashik", "Grapes", 2018, 150000],
    ["Maharashtra", "Nashik", "Grapes", 2019, 160000],
    ["Maharashtra", "Nashik", "Grapes", 2020, 170000],
]

df = pd.DataFrame(data, columns=["state","district","crop","year","production_tons"])

# save as CSV (for realism) and Parquet (for app use)
df.to_csv("data/crop_production.csv", index=False)
df.to_parquet("data/crops_clean.parquet", index=False)

df.head()
# Out:
#      state   district    crop  year  production_tons
# 0  Gujarat  Ahmedabad  Cotton  2018           250000
# 1  Gujarat  Ahmedabad  Cotton  2019           260000
# 2  Gujarat  Ahmedabad  Cotton  2020           255000
# 3  Gujarat  Ahmedabad   Wheat  2018           150000
# 4  Gujarat  Ahmedabad   Wheat  2019           158000
