# %%
import pandas as pd

# read the csv from inside the data folder
df = pd.read_csv("data/rainfall.csv")

df.head()
# Out:
#   Sl. No.      District  2014 - ANNUAL AVERAGE RAINFALL   \
# 0       1     Ahmedabad                              676
# 1       2        Amreli                              524
# 2       3         Anand                              998
# 3       4       Arvalli                              818
# 4       5  Banas Kantha                              514
#
#    2015 - ANNUAL AVERAGE RAINFALL   2016 - ANNUAL AVERAGE RAINFALL   \
# 0                              458                              419
# 1                              780                              711
# 2                              470                              492
# 3                              717                              953
# 4                              929                              466
#
#    2017 - ANNUAL AVERAGE RAINFALL   2018 - ANNUAL AVERAGE RAINFALL   \
# 0                              721                              292
# 1                              604                              501
# ...

# %%
print("Columns:", df.columns.tolist())
print("Rows:", len(df))
# Out:
# Columns: ['Sl. No.', 'District', '2014 - ANNUAL AVERAGE RAINFALL ', '2015 - ANNUAL AVERAGE RAINFALL ', '2016 - ANNUAL AVERAGE RAINFALL ', '2017 - ANNUAL AVERAGE RAINFALL ', '2018 - ANNUAL AVERAGE RAINFALL ', '2019 - ANNUAL AVERAGE RAINFALL ', '2020 - ANNUAL AVERAGE RAINFALL ', '2021 - ANNUAL AVERAGE RAINFALL ', '2022 - ANNUAL AVERAGE RAINFALL ', '2023 - ANNUAL AVERAGE RAINFALL ']
# Rows: 34
